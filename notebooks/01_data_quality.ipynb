# %% [markdown]
# # 01 — Urban-tree data quality
# Define what can be trusted before drawing Smart City conclusions.

# %%
quality_rules = {
 'required':['idbase','domanialite','arrondissement'],
 'non_negative':['hauteurenm','circonferenceencm'],
 'unique_identifier':'idbase',
 'review_flags':['height above plausible bound','circumference above plausible bound']}
quality_rules

# %% [markdown]
# Flag questionable measurements before deletion and report how each rule changes geographic and species coverage.
