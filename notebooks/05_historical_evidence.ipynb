# %% [markdown]
# # 05 — Historical Smart City evidence
# Verified checkpoints from the 87-cell public analysis notebook.

# %%
import pandas as pd
funnel=pd.DataFrame([
 {'stage':'source inventory','trees':200137},
 {'stage':'distinct coordinates','trees':200110},
 {'stage':'morphology sample','trees':160021}])
funnel

# %%
morphology=pd.Series({
 'median_circumference_cm':80.0,
 'mean_circumference_cm':92.45,
 'median_height_m':10.0,
 'mean_height_m':10.37,
 'height_circumference_pearson_r':0.7973399802,
 'represented_genera':146})
morphology

# %% [markdown]
# ## Interpretation
# The high positive association supports a morphology story but not a causal health or age model. The original notebook correctly explores separate regressions by development stage; a current production analysis would add uncertainty, spatial exposure and inventory-date validation.
