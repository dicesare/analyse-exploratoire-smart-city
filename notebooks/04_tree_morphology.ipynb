# %% [markdown]
# # 04 — Tree morphology
# Study height and circumference while making measurement error and heterogeneity visible.

# %%
observations = [
 {'height_m':8,'circumference_cm':70},
 {'height_m':12,'circumference_cm':110},
 {'height_m':18,'circumference_cm':190}]
ratios = [round(x['circumference_cm']/x['height_m'],1) for x in observations]
ratios

# %% [markdown]
# A regression describes association, not age or health. Inspect residuals by species and site, and keep extreme values as review candidates until verified.
