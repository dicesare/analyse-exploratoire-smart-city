# %% [markdown]
# # 02 — Urban distribution
# Compare tree counts across administrative areas without confusing inventory volume with vegetation density.

# %%
areas = [
 {'area':'A','trees':12000,'surface_km2':8.2},
 {'area':'B','trees':9000,'surface_km2':4.1}]
[{**x,'trees_per_km2':round(x['trees']/x['surface_km2'])} for x in areas]

# %% [markdown]
# Normalise by area, population or street length according to the policy question. Inventory coverage and observation date remain important caveats.
